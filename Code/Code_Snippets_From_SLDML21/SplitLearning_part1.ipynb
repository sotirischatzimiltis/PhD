# %% [markdown]
# #Scope
#
#
# *   Understanding Split Learning
# *   Setting up the Training Pipeline
# *   Distributed Forward and Backward Pass
# *   Scaling to multiple clients

# %% [markdown]
# #What is Split Learning?
# Split Learning is a technique for distributed training and prediction without sharing raw data. The simplest idea here is to split a neural network architecture into two parts such that the first part can be executed by a trusted client and the output of the first part is fed to the second part which is typically executed by the sever.
# This approach enables multi-client, multi-insitution collaboration for deep learning algorithms.

# %% [markdown]
# Set runtime as GPU

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
import torch.optim as optim
from torch.autograd import Variable

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))])

#CIFAR 10 is a dataset of natural images consisting of 50k training images and 10k test
#Every image is labelled with one of the following class
classes = ('plane','car','bird','cat','deer','dog','frog','horse','ship','truck')

trainset = torchvision.datasets.CIFAR10(root='./data',train = True, download = True,transform = transform)
trainloader = torch.utils.data.DataLoader(trainset,batch_size=128,shuffle= True,num_workers = 2)

testset = torchvision.datasets.CIFAR10(root = './data', train = False,download = True,transform = transform)
testloader = torch.utils.data.DataLoader(testset,batch_size = 128,shuffle = True,num_workers = 2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:11<00:00, 14782756.86it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# Pytorch provides nn.Module as a base class for all neural network modules. This allows easily creating a parameterized model.
#
# torchvision package consists of popular datasets, model architectures and common image transformations for computer vision. Here we use torchvision's model API to use ResNet18 architecture.

# %%
# Explain nn.Module and explain the forward and backward pass
class ResNet18Client(nn.Module):
    """ docstring for ResNet """
    #Explain initialize (listing the neural network architecture and other related parameters)
    def __init__(self,config):
        super(ResNet18Client,self).__init__()
        #Declare where we are going to split the NN, if cut layer close to output most computation will happen in the client side
        self.cut_layer = config["cut_layer"]

        #Load the resnet model
        self.model = models.resnet18(pretrained = False)
        self.model = nn.ModuleList(self.model.children())
        self.model = nn.Sequential(*self.model)

    def forward(self,x):
        for i,l in enumerate(self.model):
            if i> self.cut_layer:
                break
            x = l(x)
        return x

# %%
class ResNet18Server(nn.Module):
    """ docstring for ResNet """
    def __init__(self,config):
        super(ResNet18Server,self).__init__()
        self.logits = config["logits"]
        self.cut_layer = config["cut_layer"]

        self.model = models.resnet18(pretrained = False)
        num_ftrs = self.model.fc.in_features
        #
        self.model.fc = nn.Sequential(nn.Flatten(),nn.Linear(num_ftrs,self.logits))
        self.model = nn.ModuleList(self.model.children())
        self.model = nn.Sequential(*self.model)

    def forward(self,x):
        for i,l in enumerate(self.model):
            #continue until you are in the cut layer, skip earlier layers
            if i<=self.cut_layer:
                continue
            x = l(x)
        return nn.functional.softmax(x,dim=1)

# %% [markdown]
# #Initialize the Models

# %%
config = {'cut_layer':3,"logits":10} #logits = 10 cause we are using ciphar10 that has 10 classes
client_model = ResNet18Client(config).to(device)
server_model = ResNet18Server(config).to(device)

# %% [markdown]
# Set up the optimizer

# %%
criterion = nn.CrossEntropyLoss()
client_optimizer = optim.SGD(client_model.parameters(),lr=0.01,momentum=0.9)
server_optimizer = optim.SGD(server_model.parameters(),lr=0.01,momentum = 0.9)

# %% [markdown]
# Perform training

# %%
num_epochs = 50
for epoch in range(num_epochs):
    running_loss = 0.0
    for i,data in enumerate(trainloader,0):
        inputs, labels = data[0].to(device), data[1].to(device)

        client_optimizer.zero_grad()
        server_optimizer.zero_grad()

        #Client Part
        activation = client_model(inputs)
        server_inputs = activation.detach().clone() # get the outputs of the client and input them to the server

        #Simulation of sever part is happening in this portion
        #Server part
        server_inputs = Variable(server_inputs,requires_grad = True)
        outputs = server_model(server_inputs)
        loss = criterion(outputs,labels)
        loss.backward()

        #Server optimization
        server_optimizer.step()

        #Simulation of Client Happening in this portion
        #Client optimization
        activation.backward(server_inputs.grad)
        client_optimizer.step()

        running_loss += loss.item()

        if i % 200 == 199:
            print("[{},{}] loss: {}".format(epoch+1,i+1,running_loss/200))
# Out:
# [1,200] loss: 2.113515778183937
# [2,200] loss: 1.9625120824575424
# [3,200] loss: 1.8984527599811554
# [4,200] loss: 1.8545391988754272
# [5,200] loss: 1.8295815044641495
# [6,200] loss: 1.8033285665512084
# [7,200] loss: 1.782121154665947
# [8,200] loss: 1.7604520726203918
# [9,200] loss: 1.751526979804039
# [10,200] loss: 1.7327482372522354
# [11,200] loss: 1.7225162214040757
# [12,200] loss: 1.7111092078685761
# [13,200] loss: 1.6973230242729187
# [14,200] loss: 1.678701884150505
# [15,200] loss: 1.6723183631896972
# [16,200] loss: 1.6656447041034699
# [17,200] loss: 1.6526123923063278
# [18,200] loss: 1.6437605232000352
# [19,200] loss: 1.6353329992294312
# [20,200] loss: 1.6280428624153138
# [21,200] loss: 1.6256264501810074
# [22,200] loss: 1.6161740392446518
# [23,200] loss: 1.6182483959197997
# [24,200] loss: 1.607930174469948
# [25,200] loss: 1.5965617144107818
# [26,200] loss: 1.5969991654157638
# [27,200] loss: 1.588278787136078
# [28,200] loss: 1.5817531907558442
# [29,200] loss: 1.5811073738336563
# [30,200] loss: 1.5756449389457703
# [31,200] loss: 1.5713367623090744
# [32,200] loss: 1.5665088546276094
# [33,200] loss: 1.564387788772583
# [34,200] loss: 1.55739514708519
# [35,200] loss: 1.5556190878152847
# [36,200] loss: 1.5529047703742982
# [37,200] loss: 1.552558913230896
# [38,200] loss: 1.5468249601125716
# [39,200] loss: 1.5435443007946015
# [40,200] loss: 1.5434017419815063
# [41,200] loss: 1.537038580775261
# [42,200] loss: 1.5361574125289916
# [43,200] loss: 1.531697102189064
# [44,200] loss: 1.5335751450061799
# [45,200] loss: 1.5294607484340668
# [46,200] loss: 1.527406426668167
# [47,200] loss: 1.5239273899793624
# [48,200] loss: 1.5254383784532548
# [49,200] loss: 1.5231538450717925
# [50,200] loss: 1.5209192192554475

# %%
# save the model
# !mkdir = 'saved_models'

# %%
client_model_path = './saved_models/trained_client_model.pt'
server_model_path = './saved_models/trained_server_model.pt'
torch.save(client_model.state_dict(),client_model_path)
torch.save(server_model.state_dict(),server_model_path)

# %%
# Evaluation
total, correct = 0, 0
with torch.no_grad():
    for data in testloader:
        inputs, labels = data[0].to(device), data[1].to(device)
        outputs = server_model(client_model(inputs))
        _, predicted = torch.max(outputs.data,1)
        total += labels.size(0)
        correct += (predicted==labels).sum().item()
    print(correct/total)
# Out:
# 0.7283

# %% [markdown]
# # Scaling to multiple clients
# We will implement a basic round robin protocol for multiple clients to perform distributed training.
# Here each client takes part in training and then send its weight to the subsequent client who continues with the  training.
# Last 50mins of https://www.youtube.com/watch?v=VPL6ELWdJbg

# %%
total_client_num = 10
#Initialize multiple clients
client_model_list = [ResNet18Client(config).to(device) for client_num in range(total_client_num)]
#Initialize multiple optimizers
client_optimizer_list = [optim.SGD(client_model_list[client_num].parameters(),lr=0.01,momentum =0.9) for client_num in range(total_client_num)]
server = ResNet18Server(config).to(device)
server_optimizer = optim.SGD(server.parameters(),lr=0.01,momentum = 0.9)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %% [markdown]
# #Training pipeline for multiple clients

# %%
num_epochs = 50 // total_client_num
for epoch in range(num_epochs):
    # Iterate over multiple clients
    for client_num in range(total_client_num):
        print("Current active client is {}".format(client_num))
        client = client_model_list[client_num]
        clinet_optimizer = client_optimizer_list[client_num]

        #Logic to load the weights from the previous client
        if client_num ==0:
            if epoch != 0:
                prev_client = total_client_num - 1
                prev_client_weights = client_model_list[prev_client].state_dict()
                client.load_state_dict(prev_client_weights)
                print("Loaded client {}'s weight successfully".format(prev_client))
        else:
            prev_client = client_num -1
            prev_client_weights = client_model_list[prev_client].state_dict()
            client.load_state_dict(prev_client_weights)
            print("Loaded client {}'s weight successfully".format(prev_client))

        client.train()
        running_loss = 0.0
        total_samples = 0
        # All clients have their own data source and we are using a single trainloader here for illustration fo te simulated setup
        for i, data in enumerate(trainloader,0):
            inputs, labels = data[0].to(device), data[1].to(device)

            client_optimizer.zero_grad()
            server_optimizer.zero_grad()

            # Client part
            activations = client(inputs)
            server_inputs = activations.detach().clone()

            # Server part
            server_inputs  = Variable(server_inputs,requires_grad = True)
            outputs = server(server_inputs)
            loss = criterion(outputs,labels)
            loss.backward()
            server_optimizer.step()

            running_loss += loss.item()
            total_samples += labels.shape[0]

            # Client part
            activations.backward(server_inputs.grad)
            client_optimizer.step()

            if i % 50 ==1:
                print( "Cleint: {}, Epoch: {}, Iteration: {}, Loss: {:.4f}".format(client_num,epoch,i,running_loss/(i+1)))
# Out:
# Current active client is 0
# Cleint: 0, Epoch: 0, Iteration: 1, Loss: 2.3072
# Cleint: 0, Epoch: 0, Iteration: 51, Loss: 2.2307
# Cleint: 0, Epoch: 0, Iteration: 101, Loss: 2.1692
# Cleint: 0, Epoch: 0, Iteration: 151, Loss: 2.1347
# Cleint: 0, Epoch: 0, Iteration: 201, Loss: 2.1089
# Cleint: 0, Epoch: 0, Iteration: 251, Loss: 2.0867
# Cleint: 0, Epoch: 0, Iteration: 301, Loss: 2.0710
# Cleint: 0, Epoch: 0, Iteration: 351, Loss: 2.0589
# Current active client is 1
# Loaded client 0's weight successfully
# Cleint: 1, Epoch: 0, Iteration: 1, Loss: 1.9112
# Cleint: 1, Epoch: 0, Iteration: 51, Loss: 1.9247
# Cleint: 1, Epoch: 0, Iteration: 101, Loss: 1.9362
# Cleint: 1, Epoch: 0, Iteration: 151, Loss: 1.9368
# Cleint: 1, Epoch: 0, Iteration: 201, Loss: 1.9348
# Cleint: 1, Epoch: 0, Iteration: 251, Loss: 1.9342
# Cleint: 1, Epoch: 0, Iteration: 301, Loss: 1.9323
# Cleint: 1, Epoch: 0, Iteration: 351, Loss: 1.9318
# Current active client is 2
# Loaded client 1's weight successfully
# Cleint: 2, Epoch: 0, Iteration: 1, Loss: 1.8543
# Cleint: 2, Epoch: 0, Iteration: 51, Loss: 1.8811
# Cleint: 2, Epoch: 0, Iteration: 101, Loss: 1.8862
# Cleint: 2, Epoch: 0, Iteration: 151, Loss: 1.8891
# Cleint: 2, Epoch: 0, Iteration: 201, Loss: 1.8900
# Cleint: 2, Epoch: 0, Iteration: 251, Loss: 1.8913
# Cleint: 2, Epoch: 0, Iteration: 301, Loss: 1.8893
# Cleint: 2, Epoch: 0, Iteration: 351, Loss: 1.8891
# Current active client is 3
# Loaded client 2's weight successfully
# Cleint: 3, Epoch: 0, Iteration: 1, Loss: 1.8924
# Cleint: 3, Epoch: 0, Iteration: 51, Loss: 1.8608
# Cleint: 3, Epoch: 0, Iteration: 101, Loss: 1.8575
# Cleint: 3, Epoch: 0, Iteration: 151, Loss: 1.8555
# Cleint: 3, Epoch: 0, Iteration: 201, Loss: 1.8550
# Cleint: 3, Epoch: 0, Iteration: 251, Loss: 1.8559
# Cleint: 3, Epoch: 0, Iteration: 301, Loss: 1.8570
# Cleint: 3, Epoch: 0, Iteration: 351, Loss: 1.8565
# Current active client is 4
# Loaded client 3's weight successfully
# Cleint: 4, Epoch: 0, Iteration: 1, Loss: 1.8074
# Cleint: 4, Epoch: 0, Iteration: 51, Loss: 1.8357
# Cleint: 4, Epoch: 0, Iteration: 101, Loss: 1.8376
# Cleint: 4, Epoch: 0, Iteration: 151, Loss: 1.8388
# Cleint: 4, Epoch: 0, Iteration: 201, Loss: 1.8369
# Cleint: 4, Epoch: 0, Iteration: 251, Loss: 1.8372
# Cleint: 4, Epoch: 0, Iteration: 301, Loss: 1.8364
# Cleint: 4, Epoch: 0, Iteration: 351, Loss: 1.8377
# Current active client is 5
# Loaded client 4's weight successfully
# Cleint: 5, Epoch: 0, Iteration: 1, Loss: 1.8334
# Cleint: 5, Epoch: 0, Iteration: 51, Loss: 1.8172
# Cleint: 5, Epoch: 0, Iteration: 101, Loss: 1.8130
# Cleint: 5, Epoch: 0, Iteration: 151, Loss: 1.8108
# Cleint: 5, Epoch: 0, Iteration: 201, Loss: 1.8124
# Cleint: 5, Epoch: 0, Iteration: 251, Loss: 1.8149
# Cleint: 5, Epoch: 0, Iteration: 301, Loss: 1.8156
# Cleint: 5, Epoch: 0, Iteration: 351, Loss: 1.8150
# Current active client is 6
# Loaded client 5's weight successfully
# Cleint: 6, Epoch: 0, Iteration: 1, Loss: 1.7339
# Cleint: 6, Epoch: 0, Iteration: 51, Loss: 1.7965
# Cleint: 6, Epoch: 0, Iteration: 101, Loss: 1.7923
# Cleint: 6, Epoch: 0, Iteration: 151, Loss: 1.7933
# Cleint: 6, Epoch: 0, Iteration: 201, Loss: 1.7940
# Cleint: 6, Epoch: 0, Iteration: 251, Loss: 1.7965
# Cleint: 6, Epoch: 0, Iteration: 301, Loss: 1.7975
# Cleint: 6, Epoch: 0, Iteration: 351, Loss: 1.7983
# Current active client is 7
# Loaded client 6's weight successfully
# Cleint: 7, Epoch: 0, Iteration: 1, Loss: 1.7324
# Cleint: 7, Epoch: 0, Iteration: 51, Loss: 1.7893
# Cleint: 7, Epoch: 0, Iteration: 101, Loss: 1.7846
# Cleint: 7, Epoch: 0, Iteration: 151, Loss: 1.7838
# Cleint: 7, Epoch: 0, Iteration: 201, Loss: 1.7866
# Cleint: 7, Epoch: 0, Iteration: 251, Loss: 1.7864
# Cleint: 7, Epoch: 0, Iteration: 301, Loss: 1.7866
# Cleint: 7, Epoch: 0, Iteration: 351, Loss: 1.7873
# Current active client is 8
# Loaded client 7's weight successfully
# Cleint: 8, Epoch: 0, Iteration: 1, Loss: 1.7776
# Cleint: 8, Epoch: 0, Iteration: 51, Loss: 1.7731
# Cleint: 8, Epoch: 0, Iteration: 101, Loss: 1.7735
# Cleint: 8, Epoch: 0, Iteration: 151, Loss: 1.7730
# Cleint: 8, Epoch: 0, Iteration: 201, Loss: 1.7746
# Cleint: 8, Epoch: 0, Iteration: 251, Loss: 1.7738
# Cleint: 8, Epoch: 0, Iteration: 301, Loss: 1.7734
# Cleint: 8, Epoch: 0, Iteration: 351, Loss: 1.7730
# Current active client is 9
# Loaded client 8's weight successfully
# Cleint: 9, Epoch: 0, Iteration: 1, Loss: 1.7330
# Cleint: 9, Epoch: 0, Iteration: 51, Loss: 1.7456
# Cleint: 9, Epoch: 0, Iteration: 101, Loss: 1.7487
# Cleint: 9, Epoch: 0, Iteration: 151, Loss: 1.7521
# Cleint: 9, Epoch: 0, Iteration: 201, Loss: 1.7563
# Cleint: 9, Epoch: 0, Iteration: 251, Loss: 1.7566
# Cleint: 9, Epoch: 0, Iteration: 301, Loss: 1.7588
# Cleint: 9, Epoch: 0, Iteration: 351, Loss: 1.7592
# Current active client is 0
# Loaded client 9's weight successfully
# Cleint: 0, Epoch: 1, Iteration: 1, Loss: 1.7658
# Cleint: 0, Epoch: 1, Iteration: 51, Loss: 1.7314
# Cleint: 0, Epoch: 1, Iteration: 101, Loss: 1.7401
# Cleint: 0, Epoch: 1, Iteration: 151, Loss: 1.7464
# Cleint: 0, Epoch: 1, Iteration: 201, Loss: 1.7465
# Cleint: 0, Epoch: 1, Iteration: 251, Loss: 1.7474
# Cleint: 0, Epoch: 1, Iteration: 301, Loss: 1.7490
# Cleint: 0, Epoch: 1, Iteration: 351, Loss: 1.7513
# Current active client is 1
# Loaded client 0's weight successfully
# Cleint: 1, Epoch: 1, Iteration: 1, Loss: 1.7178
# Cleint: 1, Epoch: 1, Iteration: 51, Loss: 1.7324
# Cleint: 1, Epoch: 1, Iteration: 101, Loss: 1.7277
# Cleint: 1, Epoch: 1, Iteration: 151, Loss: 1.7283
# Cleint: 1, Epoch: 1, Iteration: 201, Loss: 1.7319
# Cleint: 1, Epoch: 1, Iteration: 251, Loss: 1.7337
# Cleint: 1, Epoch: 1, Iteration: 301, Loss: 1.7356
# Cleint: 1, Epoch: 1, Iteration: 351, Loss: 1.7373
# Current active client is 2
# Loaded client 1's weight successfully
# Cleint: 2, Epoch: 1, Iteration: 1, Loss: 1.7382
# Cleint: 2, Epoch: 1, Iteration: 51, Loss: 1.7222
# Cleint: 2, Epoch: 1, Iteration: 101, Loss: 1.7205
# Cleint: 2, Epoch: 1, Iteration: 151, Loss: 1.7215
# Cleint: 2, Epoch: 1, Iteration: 201, Loss: 1.7232
# Cleint: 2, Epoch: 1, Iteration: 251, Loss: 1.7243
# Cleint: 2, Epoch: 1, Iteration: 301, Loss: 1.7261
# Cleint: 2, Epoch: 1, Iteration: 351, Loss: 1.7261
# Current active client is 3
# Loaded client 2's weight successfully
# Cleint: 3, Epoch: 1, Iteration: 1, Loss: 1.7091
# Cleint: 3, Epoch: 1, Iteration: 51, Loss: 1.7127
# Cleint: 3, Epoch: 1, Iteration: 101, Loss: 1.7145
# Cleint: 3, Epoch: 1, Iteration: 151, Loss: 1.7140
# Cleint: 3, Epoch: 1, Iteration: 201, Loss: 1.7113
# Cleint: 3, Epoch: 1, Iteration: 251, Loss: 1.7170
# Cleint: 3, Epoch: 1, Iteration: 301, Loss: 1.7156
# Cleint: 3, Epoch: 1, Iteration: 351, Loss: 1.7180
# Current active client is 4
# Loaded client 3's weight successfully
# Cleint: 4, Epoch: 1, Iteration: 1, Loss: 1.6490
# Cleint: 4, Epoch: 1, Iteration: 51, Loss: 1.6871
# Cleint: 4, Epoch: 1, Iteration: 101, Loss: 1.6913
# Cleint: 4, Epoch: 1, Iteration: 151, Loss: 1.6943
# Cleint: 4, Epoch: 1, Iteration: 201, Loss: 1.6982
# Cleint: 4, Epoch: 1, Iteration: 251, Loss: 1.7019
# Cleint: 4, Epoch: 1, Iteration: 301, Loss: 1.7030
# Cleint: 4, Epoch: 1, Iteration: 351, Loss: 1.7047
# Current active client is 5
# Loaded client 4's weight successfully
# Cleint: 5, Epoch: 1, Iteration: 1, Loss: 1.6650
# Cleint: 5, Epoch: 1, Iteration: 51, Loss: 1.6853
# Cleint: 5, Epoch: 1, Iteration: 101, Loss: 1.6887
# Cleint: 5, Epoch: 1, Iteration: 151, Loss: 1.6896
# Cleint: 5, Epoch: 1, Iteration: 201, Loss: 1.6869
# Cleint: 5, Epoch: 1, Iteration: 251, Loss: 1.6911
# Cleint: 5, Epoch: 1, Iteration: 301, Loss: 1.6934
# Cleint: 5, Epoch: 1, Iteration: 351, Loss: 1.6939
# Current active client is 6
# Loaded client 5's weight successfully
# Cleint: 6, Epoch: 1, Iteration: 1, Loss: 1.7271
# Cleint: 6, Epoch: 1, Iteration: 51, Loss: 1.6797
# Cleint: 6, Epoch: 1, Iteration: 101, Loss: 1.6804
# Cleint: 6, Epoch: 1, Iteration: 151, Loss: 1.6831
# Cleint: 6, Epoch: 1, Iteration: 201, Loss: 1.6829
# Cleint: 6, Epoch: 1, Iteration: 251, Loss: 1.6830
# Cleint: 6, Epoch: 1, Iteration: 301, Loss: 1.6851
# Cleint: 6, Epoch: 1, Iteration: 351, Loss: 1.6865
# Current active client is 7
# Loaded client 6's weight successfully
# Cleint: 7, Epoch: 1, Iteration: 1, Loss: 1.6937
# Cleint: 7, Epoch: 1, Iteration: 51, Loss: 1.6785
# Cleint: 7, Epoch: 1, Iteration: 101, Loss: 1.6771
# Cleint: 7, Epoch: 1, Iteration: 151, Loss: 1.6791
# Cleint: 7, Epoch: 1, Iteration: 201, Loss: 1.6776
# Cleint: 7, Epoch: 1, Iteration: 251, Loss: 1.6792
# Cleint: 7, Epoch: 1, Iteration: 301, Loss: 1.6778
# Cleint: 7, Epoch: 1, Iteration: 351, Loss: 1.6786
# Current active client is 8
# Loaded client 7's weight successfully
# Cleint: 8, Epoch: 1, Iteration: 1, Loss: 1.6622
# Cleint: 8, Epoch: 1, Iteration: 51, Loss: 1.6619
# Cleint: 8, Epoch: 1, Iteration: 101, Loss: 1.6651
# Cleint: 8, Epoch: 1, Iteration: 151, Loss: 1.6663
# Cleint: 8, Epoch: 1, Iteration: 201, Loss: 1.6660
# Cleint: 8, Epoch: 1, Iteration: 251, Loss: 1.6676
# Cleint: 8, Epoch: 1, Iteration: 301, Loss: 1.6684
# Cleint: 8, Epoch: 1, Iteration: 351, Loss: 1.6703
# Current active client is 9
# Loaded client 8's weight successfully
# Cleint: 9, Epoch: 1, Iteration: 1, Loss: 1.6748
# Cleint: 9, Epoch: 1, Iteration: 51, Loss: 1.6657
# Cleint: 9, Epoch: 1, Iteration: 101, Loss: 1.6649
# Cleint: 9, Epoch: 1, Iteration: 151, Loss: 1.6651
# Cleint: 9, Epoch: 1, Iteration: 201, Loss: 1.6639
# Cleint: 9, Epoch: 1, Iteration: 251, Loss: 1.6641
# Cleint: 9, Epoch: 1, Iteration: 301, Loss: 1.6634
# Cleint: 9, Epoch: 1, Iteration: 351, Loss: 1.6651
# Current active client is 0
# Loaded client 9's weight successfully
# Cleint: 0, Epoch: 2, Iteration: 1, Loss: 1.6796
# Cleint: 0, Epoch: 2, Iteration: 51, Loss: 1.6544
# Cleint: 0, Epoch: 2, Iteration: 101, Loss: 1.6572
# Cleint: 0, Epoch: 2, Iteration: 151, Loss: 1.6571
# Cleint: 0, Epoch: 2, Iteration: 201, Loss: 1.6562
# Cleint: 0, Epoch: 2, Iteration: 251, Loss: 1.6558
# Cleint: 0, Epoch: 2, Iteration: 301, Loss: 1.6568
# Cleint: 0, Epoch: 2, Iteration: 351, Loss: 1.6583
# Current active client is 1
# Loaded client 0's weight successfully
# Cleint: 1, Epoch: 2, Iteration: 1, Loss: 1.6637
# Cleint: 1, Epoch: 2, Iteration: 51, Loss: 1.6517
# Cleint: 1, Epoch: 2, Iteration: 101, Loss: 1.6516
# Cleint: 1, Epoch: 2, Iteration: 151, Loss: 1.6513
# Cleint: 1, Epoch: 2, Iteration: 201, Loss: 1.6504
# Cleint: 1, Epoch: 2, Iteration: 251, Loss: 1.6513
# Cleint: 1, Epoch: 2, Iteration: 301, Loss: 1.6510
# Cleint: 1, Epoch: 2, Iteration: 351, Loss: 1.6523
# Current active client is 2
# Loaded client 1's weight successfully
# Cleint: 2, Epoch: 2, Iteration: 1, Loss: 1.6693
# Cleint: 2, Epoch: 2, Iteration: 51, Loss: 1.6410
# Cleint: 2, Epoch: 2, Iteration: 101, Loss: 1.6424
# Cleint: 2, Epoch: 2, Iteration: 151, Loss: 1.6415
# Cleint: 2, Epoch: 2, Iteration: 201, Loss: 1.6399
# Cleint: 2, Epoch: 2, Iteration: 251, Loss: 1.6385
# Cleint: 2, Epoch: 2, Iteration: 301, Loss: 1.6412
# Cleint: 2, Epoch: 2, Iteration: 351, Loss: 1.6425
# Current active client is 3
# Loaded client 2's weight successfully
# Cleint: 3, Epoch: 2, Iteration: 1, Loss: 1.6579
# Cleint: 3, Epoch: 2, Iteration: 51, Loss: 1.6310
# Cleint: 3, Epoch: 2, Iteration: 101, Loss: 1.6294
# Cleint: 3, Epoch: 2, Iteration: 151, Loss: 1.6312
# Cleint: 3, Epoch: 2, Iteration: 201, Loss: 1.6325
# Cleint: 3, Epoch: 2, Iteration: 251, Loss: 1.6325
# Cleint: 3, Epoch: 2, Iteration: 301, Loss: 1.6336
# Cleint: 3, Epoch: 2, Iteration: 351, Loss: 1.6345
# Current active client is 4
# Loaded client 3's weight successfully
# Cleint: 4, Epoch: 2, Iteration: 1, Loss: 1.6553
# Cleint: 4, Epoch: 2, Iteration: 51, Loss: 1.6281
# Cleint: 4, Epoch: 2, Iteration: 101, Loss: 1.6283
# Cleint: 4, Epoch: 2, Iteration: 151, Loss: 1.6310
# Cleint: 4, Epoch: 2, Iteration: 201, Loss: 1.6306
# Cleint: 4, Epoch: 2, Iteration: 251, Loss: 1.6322
# Cleint: 4, Epoch: 2, Iteration: 301, Loss: 1.6329
# Cleint: 4, Epoch: 2, Iteration: 351, Loss: 1.6346
# Current active client is 5
# Loaded client 4's weight successfully
# Cleint: 5, Epoch: 2, Iteration: 1, Loss: 1.6184
# Cleint: 5, Epoch: 2, Iteration: 51, Loss: 1.6286
# Cleint: 5, Epoch: 2, Iteration: 101, Loss: 1.6295
# Cleint: 5, Epoch: 2, Iteration: 151, Loss: 1.6282
# Cleint: 5, Epoch: 2, Iteration: 201, Loss: 1.6276
# Cleint: 5, Epoch: 2, Iteration: 251, Loss: 1.6289
# Cleint: 5, Epoch: 2, Iteration: 301, Loss: 1.6274
# Cleint: 5, Epoch: 2, Iteration: 351, Loss: 1.6277
# Current active client is 6
# Loaded client 5's weight successfully
# Cleint: 6, Epoch: 2, Iteration: 1, Loss: 1.6483
# Cleint: 6, Epoch: 2, Iteration: 51, Loss: 1.6154
# Cleint: 6, Epoch: 2, Iteration: 101, Loss: 1.6181
# Cleint: 6, Epoch: 2, Iteration: 151, Loss: 1.6205
# Cleint: 6, Epoch: 2, Iteration: 201, Loss: 1.6217
# Cleint: 6, Epoch: 2, Iteration: 251, Loss: 1.6220
# Cleint: 6, Epoch: 2, Iteration: 301, Loss: 1.6234
# Cleint: 6, Epoch: 2, Iteration: 351, Loss: 1.6233
# Current active client is 7
# Loaded client 6's weight successfully
# Cleint: 7, Epoch: 2, Iteration: 1, Loss: 1.6500
# Cleint: 7, Epoch: 2, Iteration: 51, Loss: 1.6170
# Cleint: 7, Epoch: 2, Iteration: 101, Loss: 1.6072
# Cleint: 7, Epoch: 2, Iteration: 151, Loss: 1.6109
# Cleint: 7, Epoch: 2, Iteration: 201, Loss: 1.6141
# Cleint: 7, Epoch: 2, Iteration: 251, Loss: 1.6149
# Cleint: 7, Epoch: 2, Iteration: 301, Loss: 1.6155
# Cleint: 7, Epoch: 2, Iteration: 351, Loss: 1.6178
# Current active client is 8
# Loaded client 7's weight successfully
# Cleint: 8, Epoch: 2, Iteration: 1, Loss: 1.5909
# Cleint: 8, Epoch: 2, Iteration: 51, Loss: 1.6202
# Cleint: 8, Epoch: 2, Iteration: 101, Loss: 1.6142
# Cleint: 8, Epoch: 2, Iteration: 151, Loss: 1.6132
# Cleint: 8, Epoch: 2, Iteration: 201, Loss: 1.6137
# Cleint: 8, Epoch: 2, Iteration: 251, Loss: 1.6124
# Cleint: 8, Epoch: 2, Iteration: 301, Loss: 1.6138
# Cleint: 8, Epoch: 2, Iteration: 351, Loss: 1.6143
# Current active client is 9
# Loaded client 8's weight successfully
# Cleint: 9, Epoch: 2, Iteration: 1, Loss: 1.6266
# Cleint: 9, Epoch: 2, Iteration: 51, Loss: 1.6042
# Cleint: 9, Epoch: 2, Iteration: 101, Loss: 1.6042
# Cleint: 9, Epoch: 2, Iteration: 151, Loss: 1.6058
# Cleint: 9, Epoch: 2, Iteration: 201, Loss: 1.6056
# Cleint: 9, Epoch: 2, Iteration: 251, Loss: 1.6049
# Cleint: 9, Epoch: 2, Iteration: 301, Loss: 1.6058
# Cleint: 9, Epoch: 2, Iteration: 351, Loss: 1.6064
# Current active client is 0
# Loaded client 9's weight successfully
# Cleint: 0, Epoch: 3, Iteration: 1, Loss: 1.5810
# Cleint: 0, Epoch: 3, Iteration: 51, Loss: 1.6003
# Cleint: 0, Epoch: 3, Iteration: 101, Loss: 1.6006
# Cleint: 0, Epoch: 3, Iteration: 151, Loss: 1.5994
# Cleint: 0, Epoch: 3, Iteration: 201, Loss: 1.5999
# Cleint: 0, Epoch: 3, Iteration: 251, Loss: 1.6005
# Cleint: 0, Epoch: 3, Iteration: 301, Loss: 1.6020
# Cleint: 0, Epoch: 3, Iteration: 351, Loss: 1.6036
# Current active client is 1
# Loaded client 0's weight successfully
# Cleint: 1, Epoch: 3, Iteration: 1, Loss: 1.5940
# Cleint: 1, Epoch: 3, Iteration: 51, Loss: 1.5988
# Cleint: 1, Epoch: 3, Iteration: 101, Loss: 1.6018
# Cleint: 1, Epoch: 3, Iteration: 151, Loss: 1.6031
# Cleint: 1, Epoch: 3, Iteration: 201, Loss: 1.6001
# Cleint: 1, Epoch: 3, Iteration: 251, Loss: 1.5993
# Cleint: 1, Epoch: 3, Iteration: 301, Loss: 1.5996
# Cleint: 1, Epoch: 3, Iteration: 351, Loss: 1.5999
# Current active client is 2
# Loaded client 1's weight successfully
# Cleint: 2, Epoch: 3, Iteration: 1, Loss: 1.6001
# Cleint: 2, Epoch: 3, Iteration: 51, Loss: 1.5918
# Cleint: 2, Epoch: 3, Iteration: 101, Loss: 1.5918
# Cleint: 2, Epoch: 3, Iteration: 151, Loss: 1.5941
# Cleint: 2, Epoch: 3, Iteration: 201, Loss: 1.5934
# Cleint: 2, Epoch: 3, Iteration: 251, Loss: 1.5945
# Cleint: 2, Epoch: 3, Iteration: 301, Loss: 1.5952
# Cleint: 2, Epoch: 3, Iteration: 351, Loss: 1.5939
# Current active client is 3
# Loaded client 2's weight successfully
# Cleint: 3, Epoch: 3, Iteration: 1, Loss: 1.5915
# Cleint: 3, Epoch: 3, Iteration: 51, Loss: 1.5920
# Cleint: 3, Epoch: 3, Iteration: 101, Loss: 1.5917
# Cleint: 3, Epoch: 3, Iteration: 151, Loss: 1.5935
# Cleint: 3, Epoch: 3, Iteration: 201, Loss: 1.5925
# Cleint: 3, Epoch: 3, Iteration: 251, Loss: 1.5929
# Cleint: 3, Epoch: 3, Iteration: 301, Loss: 1.5920
# Cleint: 3, Epoch: 3, Iteration: 351, Loss: 1.5920
# Current active client is 4
# Loaded client 3's weight successfully
# Cleint: 4, Epoch: 3, Iteration: 1, Loss: 1.6143
# Cleint: 4, Epoch: 3, Iteration: 51, Loss: 1.5815
# Cleint: 4, Epoch: 3, Iteration: 101, Loss: 1.5812
# Cleint: 4, Epoch: 3, Iteration: 151, Loss: 1.5820
# Cleint: 4, Epoch: 3, Iteration: 201, Loss: 1.5839
# Cleint: 4, Epoch: 3, Iteration: 251, Loss: 1.5845
# Cleint: 4, Epoch: 3, Iteration: 301, Loss: 1.5863
# Cleint: 4, Epoch: 3, Iteration: 351, Loss: 1.5875
# Current active client is 5
# Loaded client 4's weight successfully
# Cleint: 5, Epoch: 3, Iteration: 1, Loss: 1.6229
# Cleint: 5, Epoch: 3, Iteration: 51, Loss: 1.5846
# Cleint: 5, Epoch: 3, Iteration: 101, Loss: 1.5809
# Cleint: 5, Epoch: 3, Iteration: 151, Loss: 1.5816
# Cleint: 5, Epoch: 3, Iteration: 201, Loss: 1.5846
# Cleint: 5, Epoch: 3, Iteration: 251, Loss: 1.5841
# Cleint: 5, Epoch: 3, Iteration: 301, Loss: 1.5827
# Cleint: 5, Epoch: 3, Iteration: 351, Loss: 1.5823
# Current active client is 6
# Loaded client 5's weight successfully
# Cleint: 6, Epoch: 3, Iteration: 1, Loss: 1.5546
# Cleint: 6, Epoch: 3, Iteration: 51, Loss: 1.5782
# Cleint: 6, Epoch: 3, Iteration: 101, Loss: 1.5760
# Cleint: 6, Epoch: 3, Iteration: 151, Loss: 1.5749
# Cleint: 6, Epoch: 3, Iteration: 201, Loss: 1.5760
# Cleint: 6, Epoch: 3, Iteration: 251, Loss: 1.5759
# Cleint: 6, Epoch: 3, Iteration: 301, Loss: 1.5772
# Cleint: 6, Epoch: 3, Iteration: 351, Loss: 1.5779
# Current active client is 7
# Loaded client 6's weight successfully
# Cleint: 7, Epoch: 3, Iteration: 1, Loss: 1.5860
# Cleint: 7, Epoch: 3, Iteration: 51, Loss: 1.5702
# Cleint: 7, Epoch: 3, Iteration: 101, Loss: 1.5728
# Cleint: 7, Epoch: 3, Iteration: 151, Loss: 1.5735
# Cleint: 7, Epoch: 3, Iteration: 201, Loss: 1.5732
# Cleint: 7, Epoch: 3, Iteration: 251, Loss: 1.5732
# Cleint: 7, Epoch: 3, Iteration: 301, Loss: 1.5738
# Cleint: 7, Epoch: 3, Iteration: 351, Loss: 1.5749
# Current active client is 8
# Loaded client 7's weight successfully
# Cleint: 8, Epoch: 3, Iteration: 1, Loss: 1.6120
# Cleint: 8, Epoch: 3, Iteration: 51, Loss: 1.5789
# Cleint: 8, Epoch: 3, Iteration: 101, Loss: 1.5771
# Cleint: 8, Epoch: 3, Iteration: 151, Loss: 1.5776
# Cleint: 8, Epoch: 3, Iteration: 201, Loss: 1.5778
# Cleint: 8, Epoch: 3, Iteration: 251, Loss: 1.5773
# Cleint: 8, Epoch: 3, Iteration: 301, Loss: 1.5757
# Cleint: 8, Epoch: 3, Iteration: 351, Loss: 1.5757
# Current active client is 9
# Loaded client 8's weight successfully
# Cleint: 9, Epoch: 3, Iteration: 1, Loss: 1.5948
# Cleint: 9, Epoch: 3, Iteration: 51, Loss: 1.5757
# Cleint: 9, Epoch: 3, Iteration: 101, Loss: 1.5732
# Cleint: 9, Epoch: 3, Iteration: 151, Loss: 1.5728
# Cleint: 9, Epoch: 3, Iteration: 201, Loss: 1.5713
# Cleint: 9, Epoch: 3, Iteration: 251, Loss: 1.5721
# Cleint: 9, Epoch: 3, Iteration: 301, Loss: 1.5721
# Cleint: 9, Epoch: 3, Iteration: 351, Loss: 1.5722
# Current active client is 0
# Loaded client 9's weight successfully
# Cleint: 0, Epoch: 4, Iteration: 1, Loss: 1.5565
# Cleint: 0, Epoch: 4, Iteration: 51, Loss: 1.5657
# Cleint: 0, Epoch: 4, Iteration: 101, Loss: 1.5674
# Cleint: 0, Epoch: 4, Iteration: 151, Loss: 1.5674
# Cleint: 0, Epoch: 4, Iteration: 201, Loss: 1.5681
# Cleint: 0, Epoch: 4, Iteration: 251, Loss: 1.5685
# Cleint: 0, Epoch: 4, Iteration: 301, Loss: 1.5673
# Cleint: 0, Epoch: 4, Iteration: 351, Loss: 1.5676
# Current active client is 1
# Loaded client 0's weight successfully
# Cleint: 1, Epoch: 4, Iteration: 1, Loss: 1.5560
# Cleint: 1, Epoch: 4, Iteration: 51, Loss: 1.5564
# Cleint: 1, Epoch: 4, Iteration: 101, Loss: 1.5569
# Cleint: 1, Epoch: 4, Iteration: 151, Loss: 1.5597
# Cleint: 1, Epoch: 4, Iteration: 201, Loss: 1.5621
# Cleint: 1, Epoch: 4, Iteration: 251, Loss: 1.5631
# Cleint: 1, Epoch: 4, Iteration: 301, Loss: 1.5643
# Cleint: 1, Epoch: 4, Iteration: 351, Loss: 1.5644
# Current active client is 2
# Loaded client 1's weight successfully
# Cleint: 2, Epoch: 4, Iteration: 1, Loss: 1.5478
# Cleint: 2, Epoch: 4, Iteration: 51, Loss: 1.5604
# Cleint: 2, Epoch: 4, Iteration: 101, Loss: 1.5607
# Cleint: 2, Epoch: 4, Iteration: 151, Loss: 1.5609
# Cleint: 2, Epoch: 4, Iteration: 201, Loss: 1.5623
# Cleint: 2, Epoch: 4, Iteration: 251, Loss: 1.5630
# Cleint: 2, Epoch: 4, Iteration: 301, Loss: 1.5625
# Cleint: 2, Epoch: 4, Iteration: 351, Loss: 1.5635
# Current active client is 3
# Loaded client 2's weight successfully
# Cleint: 3, Epoch: 4, Iteration: 1, Loss: 1.5706
# Cleint: 3, Epoch: 4, Iteration: 51, Loss: 1.5565
# Cleint: 3, Epoch: 4, Iteration: 101, Loss: 1.5586
# Cleint: 3, Epoch: 4, Iteration: 151, Loss: 1.5596
# Cleint: 3, Epoch: 4, Iteration: 201, Loss: 1.5603
# Cleint: 3, Epoch: 4, Iteration: 251, Loss: 1.5620
# Cleint: 3, Epoch: 4, Iteration: 301, Loss: 1.5629
# Cleint: 3, Epoch: 4, Iteration: 351, Loss: 1.5631
# Current active client is 4
# Loaded client 3's weight successfully
# Cleint: 4, Epoch: 4, Iteration: 1, Loss: 1.5340
# Cleint: 4, Epoch: 4, Iteration: 51, Loss: 1.5638
# Cleint: 4, Epoch: 4, Iteration: 101, Loss: 1.5623
# Cleint: 4, Epoch: 4, Iteration: 151, Loss: 1.5622
# Cleint: 4, Epoch: 4, Iteration: 201, Loss: 1.5616
# Cleint: 4, Epoch: 4, Iteration: 251, Loss: 1.5614
# Cleint: 4, Epoch: 4, Iteration: 301, Loss: 1.5609
# Cleint: 4, Epoch: 4, Iteration: 351, Loss: 1.5597
# Current active client is 5
# Loaded client 4's weight successfully
# Cleint: 5, Epoch: 4, Iteration: 1, Loss: 1.5438
# Cleint: 5, Epoch: 4, Iteration: 51, Loss: 1.5484
# Cleint: 5, Epoch: 4, Iteration: 101, Loss: 1.5490
# Cleint: 5, Epoch: 4, Iteration: 151, Loss: 1.5508
# Cleint: 5, Epoch: 4, Iteration: 201, Loss: 1.5535
# Cleint: 5, Epoch: 4, Iteration: 251, Loss: 1.5535
# Cleint: 5, Epoch: 4, Iteration: 301, Loss: 1.5542
# Cleint: 5, Epoch: 4, Iteration: 351, Loss: 1.5541
# Current active client is 6
# Loaded client 5's weight successfully
# Cleint: 6, Epoch: 4, Iteration: 1, Loss: 1.5475
# Cleint: 6, Epoch: 4, Iteration: 51, Loss: 1.5521
# Cleint: 6, Epoch: 4, Iteration: 101, Loss: 1.5537
# Cleint: 6, Epoch: 4, Iteration: 151, Loss: 1.5518
# Cleint: 6, Epoch: 4, Iteration: 201, Loss: 1.5513
# Cleint: 6, Epoch: 4, Iteration: 251, Loss: 1.5517
# Cleint: 6, Epoch: 4, Iteration: 301, Loss: 1.5533
# Cleint: 6, Epoch: 4, Iteration: 351, Loss: 1.5541
# Current active client is 7
# Loaded client 6's weight successfully
# Cleint: 7, Epoch: 4, Iteration: 1, Loss: 1.5563
# Cleint: 7, Epoch: 4, Iteration: 51, Loss: 1.5508
# Cleint: 7, Epoch: 4, Iteration: 101, Loss: 1.5510
# Cleint: 7, Epoch: 4, Iteration: 151, Loss: 1.5504
# Cleint: 7, Epoch: 4, Iteration: 201, Loss: 1.5518
# Cleint: 7, Epoch: 4, Iteration: 251, Loss: 1.5534
# Cleint: 7, Epoch: 4, Iteration: 301, Loss: 1.5530
# Cleint: 7, Epoch: 4, Iteration: 351, Loss: 1.5522
# Current active client is 8
# Loaded client 7's weight successfully
# Cleint: 8, Epoch: 4, Iteration: 1, Loss: 1.5409
# Cleint: 8, Epoch: 4, Iteration: 51, Loss: 1.5520
# Cleint: 8, Epoch: 4, Iteration: 101, Loss: 1.5502
# Cleint: 8, Epoch: 4, Iteration: 151, Loss: 1.5527
# Cleint: 8, Epoch: 4, Iteration: 201, Loss: 1.5519
# Cleint: 8, Epoch: 4, Iteration: 251, Loss: 1.5504
# Cleint: 8, Epoch: 4, Iteration: 301, Loss: 1.5504
# Cleint: 8, Epoch: 4, Iteration: 351, Loss: 1.5505
# Current active client is 9
# Loaded client 8's weight successfully
# Cleint: 9, Epoch: 4, Iteration: 1, Loss: 1.5681
# Cleint: 9, Epoch: 4, Iteration: 51, Loss: 1.5450
# Cleint: 9, Epoch: 4, Iteration: 101, Loss: 1.5460
# Cleint: 9, Epoch: 4, Iteration: 151, Loss: 1.5458
# Cleint: 9, Epoch: 4, Iteration: 201, Loss: 1.5460
# Cleint: 9, Epoch: 4, Iteration: 251, Loss: 1.5468
# Cleint: 9, Epoch: 4, Iteration: 301, Loss: 1.5473
# Cleint: 9, Epoch: 4, Iteration: 351, Loss: 1.5471

# %% [markdown]
# # Future Directions
# 1. How to make the round robin protocol asynchronous?
# 2. Different data distribution across clients?
# 3. Different topologies of client models, multiple servers, etc.
